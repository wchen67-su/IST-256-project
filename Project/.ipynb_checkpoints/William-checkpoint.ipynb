# %%
import requests
import pandas as pd
import random
from IPython.display import Markdown, display
from PIL import Image
from io import BytesIO

# %%
page_number = 0
overview_length = 0
movies = 0
count = 1

def printbold(string):
    display(Markdown(string))
    
def moviegenerator():
    amount_of_movies = []
    while(len(amount_of_movies)-1<0):
        global page_number
        page_number = str(random.randint(0,1000))
        api_key = 'ed49669e2301eefe165a22a0551c3496'
        response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=' +  api_key + '&language=en-US&page=' + page_number)
        global movies
        movies = response.json()
        try:
            for i in range(0,len(movies['results'])):
                amount_of_movies.append(movies['results'][i].get('title'))
        except KeyError: 'results'
    if(len(amount_of_movies)!=0):
        global overview_length
        overview_length = random.randint(0,len(amount_of_movies)-1)

def getOverview():
    return movies['results'][overview_length].get('overview')

def getTitle():
    return movies['results'][overview_length].get('title')

def getReleasedate():
    return movies['results'][overview_length].get('release_date')

def getAverageRating():
    return movies['results'][overview_length].get('vote_average')

def getVoteCount():
    return movies['results'][overview_length].get('vote_count')

def getGenre():
    genres = []
    all_genres = []
    genre_names = []
    api_key = 'ed49669e2301eefe165a22a0551c3496'
    our_movie_genre_ids =  movies['results'][overview_length].get('genre_ids')
    genre_response = requests.get('https://api.themoviedb.org/3/genre/movie/list?api_key=' +  api_key + '&language=en-US')
    genre = genre_response.json()
    for i in range(0,len(genre['genres'])):
        all_genres.append(genre['genres'][i].get('id'))
        genre_names.append(genre['genres'][i].get('name'))

    for i in range(0,len(our_movie_genre_ids)):
        for j in range(0,len(all_genres)):
            if our_movie_genre_ids[i] == all_genres[j]:
                genres.append(genre_names[j])
    return genres

def getPosterpath():
    return movies['results'][overview_length].get('poster_path')

def getMoviePoster():
    poster_url = ('https://image.tmdb.org/t/p/w300/' + getPosterpath())
    response = requests.get(poster_url)
    img = Image.open(BytesIO(response.content))
    return img

#main function
stop = True
while stop:
    moviegenerator()
    while getOverview() == '':
        moviegenerator()
    printbold('**Generating a movie description...**')
    print(str(count)+'.', getOverview()+'\n')
    user_input = input("Does this movie sound interesting to you? Please type yes or no: ").lower()

    while True:
        if user_input == 'yes':
            printbold('**Retrieving movie details...**')
            display(getMoviePoster())
            printbold("**Title:**" + ' ' + getTitle())
            printbold("**Genres:**" + ' ' + str(getGenre()))
            printbold("**Release Date (year-month-date):**" + ' ' + getReleasedate())
            printbold("**Amount of votes:**" + ' ' + str(getVoteCount()))
            printbold("**Average Rating (Based on user votes, out of 10):**" + ' ' + str(getAverageRating()))
            printbold("**Description:**" + ' ' + str(getOverview()))
            stop = False
            break
        elif user_input == 'no':
            count = count + 1
            break
        else:
            print("Invalid input. Please type yes or no: ")
            user_input = input("Does this movie sound interesting to you? Please type yes or no: ").lower()
# Out:
# **Generating a movie description...**
# 1. A medical school dropout loses his fiancée in a tragic lawnmower incident and decides to bring her back to life. Unfortunately, he was only able to save her head, so he goes to the red light district in the city and lures prostitutes into a hotel room so he can collect body parts to reassemble her.
#
# Does this movie sound interesting to you? Please type yes or no: ijawd
# Invalid input. Please type yes or no:
# Does this movie sound interesting to you? Please type yes or no: MK
# Invalid input. Please type yes or no:
# Does this movie sound interesting to you? Please type yes or no: NO
# **Generating a movie description...**
# 2. It has been five years since the disappearance of Katie and Hunter, and a suburban family witness strange events in their neighborhood when a woman and a mysterious child move in.
#
# Does this movie sound interesting to you? Please type yes or no: YES
# **Retrieving movie details...**
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x450 at 0x1CAC66E1518>
# **Title:** Paranormal Activity 4
# **Genres:** ['Horror']
# **Release Date (year-month-date):** 2012-10-17
# **Amount of votes:** 991
# **Average Rating (Based on user votes, out of 10):** 5.3
# **Description:** It has been five years since the disappearance of Katie and Hunter, and a suburban family witness strange events in their neighborhood when a woman and a mysterious child move in.
